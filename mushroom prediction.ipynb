# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("C:\\Users\\Aditya\\OneDrive\\Desktop\\mushrooms.csv")

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
df.shape
# Out:
# (8124, 23)

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df['class'].unique()
# Out:
# array(['p', 'e'], dtype=object)

# %%
df['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.figure(figsize=(10,5))

sns.countplot(x='class', data=df)
plt.title('no of poisonus and edible mushrooms')
# Out:
# Text(0.5, 1.0, 'no of poisonus and edible mushrooms')

# %%
#the above plot shows that data in the class is balanced
#now we check the information of the data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
#features are in the form of object data type, we have to convert it into numbers by using lebelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder=LabelEncoder()
for column in df.columns:
    df[column]=labelencoder.fit_transform(df[column])

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-below-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# ...

# %%
df.tail()
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 8119                0             0          0          11  ...
# 8120                0             0          0          11  ...
# 8121                0             0          0           5  ...
# 8122                1             0          1           0  ...
# 8123                0             0          0          11  ...
#
#       stalk-surface-below-ring  stalk-color-above-ring  \
# 8119                         2                       5
# 8120                         2                       5
# ...

# %%
df['cap-shape'].unique(), df['cap-surface'].unique(), df['cap-color'].unique(), df['bruises'].unique(),df['odor'].unique(),df['gill-attachment'].unique(),df['gill-spacing'].unique(),df['gill-size'].unique(),df['gill-color'].unique(),df['stalk-shape'].unique(),df['stalk-root'].unique(),df['stalk-surface-above-ring'].unique(),df['stalk-surface-below-ring'].unique(),df['stalk-color-above-ring'].unique(),df['stalk-color-below-ring'].unique(),df['veil-type'].unique(),df['veil-color'].unique(),df['ring-number'].unique(),df['ring-type'].unique(),df['spore-print-color'].unique(),df['population'].unique(),df['habitat'].unique()
# Out:
# (array([5, 0, 4, 2, 3, 1]),
#  array([2, 3, 0, 1]),
#  array([4, 9, 8, 3, 2, 5, 0, 7, 1, 6]),
#  array([1, 0]),
#  array([6, 0, 3, 5, 2, 1, 8, 7, 4]),
#  array([1, 0]),
#  array([0, 1]),
#  array([1, 0]),
#  array([ 4,  5,  2,  7, 10,  3,  9,  1,  0,  8, 11,  6]),
#  array([0, 1]),
#  array([3, 2, 1, 4, 0]),
#  array([2, 0, 1, 3]),
#  array([2, 0, 3, 1]),
#  array([7, 3, 6, 4, 0, 2, 5, 1, 8]),
#  array([7, 6, 3, 0, 4, 2, 8, 5, 1]),
#  array([0]),
#  array([2, 0, 1, 3]),
#  array([1, 2, 0]),
#  array([4, 0, 2, 1, 3]),
#  array([2, 3, 6, 1, 7, 5, 4, 8, 0]),
#  array([3, 2, 0, 4, 5, 1]),
#  array([5, 1, 3, 0, 4, 6, 2]))

# %%
df['veil-type'].value_counts()
# Out:
# 0    8124
# Name: veil-type, dtype: int64

# %%
plt.figure(figsize=(22,16))
sns.heatmap(df.corr(),annot=True,annot_kws={'size':12})
plt.show()

# %% [markdown]
# from the heat map we observed as veil_type is not usefull because it has zeros only so we remove it from features

# %%
new_df=df.drop(columns=['veil-type'])

# %%
new_df.shape #shape after removed the veil_type
# Out:
# (8124, 22)

# %%
plt.figure(figsize=(22,16))
sns.heatmap(new_df.corr(),annot=True,annot_kws={'size':12})
plt.show()

# %%
#rename the column names as per our convenvience 
new_df.rename(columns={'cap-shape':'cap_shape','cap-surface':'cap_surface','cap-color':'cap_color','gill-attachment':'gill_attachment','gill-spacing':'gill_spacing','gill-size':'gill_size','gill-color':'gill_color','stalk-shape':'stalk_shape','stalk-root':'stalk_root','stalk-surface-above-ring':'stalk_surface_above_ring','stalk-surface-below-ring':'stalk_surface_below_ring','stalk-color-below-ring':'stalk_color_below_ring','veil-color':'veil_color','ring-number':'ring_number','ring-type':'ring_type','spore-print-color':'spore_print_color'},inplace=True)

# %%
new_df.columns #check names are changed ro not
# Out:
# Index(['class', 'cap_shape', 'cap_surface', 'cap_color', 'bruises', 'odor',
#        'gill_attachment', 'gill_spacing', 'gill_size', 'gill_color',
#        'stalk_shape', 'stalk_root', 'stalk_surface_above_ring',
#        'stalk_surface_below_ring', 'stalk-color-above-ring',
#        'stalk_color_below_ring', 'veil_color', 'ring_number', 'ring_type',
#        'spore_print_color', 'population', 'habitat'],
#       dtype='object')

# %%
new_df.shape
# Out:
# (8124, 22)

# %%
#make sure they are really correlated (it should follow the same trend)
plt.figure(figsize=(15,10))

sns.violinplot(x='gill_attachment',y='veil_color',data=new_df)
# Out:
# <AxesSubplot:xlabel='gill_attachment', ylabel='veil_color'>

# %% [markdown]
# from the above diagram we cannot say which one is more related with label so we use heat map and remove one feature between two

# %%
#veil_color is more related comparing with gill attachment so we remove gill_attachment
x=new_df.drop(columns=['gill_attachment','class'])
y=new_df['class']

# %%
x.shape
# Out:
# (8124, 20)

# %%
#standardizing the data
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
x_scaled=scalar.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,random_state=30)

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg=LogisticRegression()

# %%
lg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lg.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 1, 1, 0])

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9626743232157506

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1259,   45],
#        [  46, 1088]], dtype=int64)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97      1304
#            1       0.96      0.96      0.96      1134
#
#     accuracy                           0.96      2438
#    macro avg       0.96      0.96      0.96      2438
# weighted avg       0.96      0.96      0.96      2438

# %% [markdown]
# # KNN Model

# %%
#applying knn model 
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knn.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
#accuracy score is 1.0 it is looks like our model is overfitting so we check if it is over
#fitting or not by using cross validation score
from sklearn.model_selection import cross_val_score
cross_val_score(knn,x_scaled,y,cv=10)
# Out:
# array([0.68511685, 1.        , 1.        , 1.        , 0.99876847,
#        1.        , 1.        , 1.        , 0.83374384, 0.99261084])

# %%
cross_val_score(KNeighborsClassifier(),x_scaled,y,cv=5).mean()
# Out:
# 0.8797053429329292

# %% [markdown]
# we absorve that from cross validation accuracy score is drastically different so we confirm that our model is overfitting

# %% [markdown]
# we use hyperparameter tunning for improve accuracy

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'algorithm':['kd_tree','brute'],'leaf_size':[1,5,8,4,2],'n_neighbors':range(1,5)}

# %%
gridsearch=GridSearchCV(estimator=knn,param_grid=param_grid)

# %%
gridsearch.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['kd_tree', 'brute'],
#                          'leaf_size': [1, 5, 8, 4, 2],
#                          'n_neighbors': range(1, 5)})

# %%
gridsearch.best_params_
# Out:
# {'algorithm': 'kd_tree', 'leaf_size': 1, 'n_neighbors': 1}

# %%
knn=KNeighborsClassifier(algorithm='kd_tree',leaf_size=1,n_neighbors=1)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='kd_tree', leaf_size=1, n_neighbors=1)

# %%
y_pred=knn.predict(x_test)

# %%
cfm=confusion_matrix(y_test,y_pred)
cfm
# Out:
# array([[1304,    0],
#        [   0, 1134]], dtype=int64)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1304
#            1       1.00      1.00      1.00      1134
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438
