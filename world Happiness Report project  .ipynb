# %%
import pandas as pd 
import numpy as np

# %%
data=pd.read_csv("C:/Users/Aditya/OneDrive/Desktop/happiness_score_dataset.csv")
data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
data.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
data['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# Australia and New Zealand           2
# North America                       2
# Name: Region, dtype: int64

# %%
#rename the clumn names for our convenience
data.rename(columns={'Country':'Country','Region':'Region','Happiness Rank':'Rank','Happiness Score':'Score','Standard Error':'Error','Economy (GDP per Capita)':'Economy','Family':'Family','Health (Life Expectancy)':'Health','Freedom':'Freedom','Trust (Government Corruption)':'Trust','Generosity':'Generosity','Dystopia Residual':'Dystopia_Residual'},inplace=True)
data
# Out:
#          Country                           Region  Rank  Score    Error  \
# 0    Switzerland                   Western Europe     1  7.587  0.03411
# 1        Iceland                   Western Europe     2  7.561  0.04884
# 2        Denmark                   Western Europe     3  7.527  0.03328
# 3         Norway                   Western Europe     4  7.522  0.03880
# 4         Canada                    North America     5  7.427  0.03553
# ..           ...                              ...   ...    ...      ...
# 153       Rwanda               Sub-Saharan Africa   154  3.465  0.03464
# 154        Benin               Sub-Saharan Africa   155  3.340  0.03656
# 155        Syria  Middle East and Northern Africa   156  3.006  0.05015
# 156      Burundi               Sub-Saharan Africa   157  2.905  0.08658
# 157         Togo               Sub-Saharan Africa   158  2.839  0.06727
#
#      Economy   Family   Health  Freedom    Trust  Generosity  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %warnings inline
# Out:
# UsageError: Line magic function `%warnings` not found.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
sns.heatmap(data.corr(),cmap='coolwarm',ax=ax,annot=True,linewidths=2)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))

plt.title("score vs rank")
sns.scatterplot(data=data, x='Rank', y='Score');

# %%
#from the above plot rank is highly negatively corelated with the score so we're removing the rank from the data set

#drop the rank column and region also 

new_df=data.drop(['Rank','Region','Country','Error'],axis=1)
new_df
# Out:
#      Score  Economy   Family   Health  Freedom    Trust  Generosity  \
# 0    7.587  1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# 1    7.561  1.30232  1.40223  0.94784  0.62877  0.14145     0.43630
# 2    7.527  1.32548  1.36058  0.87464  0.64938  0.48357     0.34139
# 3    7.522  1.45900  1.33095  0.88521  0.66973  0.36503     0.34699
# 4    7.427  1.32629  1.32261  0.90563  0.63297  0.32957     0.45811
# ..     ...      ...      ...      ...      ...      ...         ...
# 153  3.465  0.22208  0.77370  0.42864  0.59201  0.55191     0.22628
# 154  3.340  0.28665  0.35386  0.31910  0.48450  0.08010     0.18260
# 155  3.006  0.66320  0.47489  0.72193  0.15684  0.18906     0.47179
# 156  2.905  0.01530  0.41587  0.22396  0.11850  0.10062     0.19727
# 157  2.839  0.20868  0.13995  0.28443  0.36453  0.10731     0.16681
#
#      Dystopia_Residual
# 0              2.51738
# 1              2.70201
# 2              2.49204
# 3              2.46531
# 4              2.45176
# ...

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
sns.heatmap(new_df.corr(),cmap='coolwarm',ax=ax,annot=True,linewidths=2)
# Out:
# <AxesSubplot:>

# %%
new_df.hist('Score')
# Out:
# array([[<AxesSubplot:title={'center':'Score'}>]], dtype=object)

# %%
sns.distplot(new_df['Score'])
# Out:
# <AxesSubplot:xlabel='Score', ylabel='Density'>

# %%
plt.figure(figsize=(15,35))
graph=1

for column in new_df:
    if graph<=25:
        ax=plt.subplot(5,2,graph)
        sns.boxplot(new_df[column])
        plt.xlabel(column,fontsize=10)
        graph+=1
        
    plt.show()

# %%
#to remove outliers by using IQR method
#1st quantile
q1=new_df.quantile(0.25)
#3rd quantile
q3=new_df.quantile(0.75)
#IQR
iqr=q3-q1

# %%
#outliers in family 
low_family=(q1.Family-(1.5*iqr.Family))
low_family
# Out:
# 0.32044875000000017

# %%
#check the indexes which have lower values 
index=np.where(new_df['Family']<low_family)
index
# Out:
# (array([147, 152, 157], dtype=int64),)

# %%
new_df=new_df.drop(new_df.index[index],axis=0)
new_df.shape
# Out:
# (155, 8)

# %%
trust_high=(q3.Trust+(1.5*iqr.Trust))
trust_high
# Out:
# 0.35812499999999997

# %%
index=np.where(new_df['Trust']>trust_high)
index
# Out:
# (array([  0,   2,   3,   5,   7,   8,  16,  19,  23,  27,  71,  90, 129,
#         151], dtype=int64),)

# %%
new_df=new_df.drop(new_df.index[index])
new_df.shape
# Out:
# (141, 8)

# %%
genrsty_high=(q3.Generosity+(1.5*iqr.Generosity))
genrsty_high
# Out:
# 0.5488775

# %%
index=np.where(new_df['Generosity']>genrsty_high)
index
# Out:
# (array([ 23, 116], dtype=int64),)

# %%
new_df=new_df.drop(new_df.index[index])
new_df.shape
# Out:
# (139, 8)

# %%
#dystopia has outliers in both sides 
dystopia_high=(q3.Dystopia_Residual+(1.5*iqr.Dystopia_Residual))
dystopia_high
# Out:
# 3.5169225

# %%
index=np.where(new_df['Dystopia_Residual']>dystopia_high)
index
# Out:
# (array([7], dtype=int64),)

# %%
new_df=new_df.drop(new_df.index[index])
new_df.shape
# Out:
# (138, 8)

# %%
#outliers present in lower side
dystopia_low=(q1.Dystopia_Residual-(1.5*iqr.Dystopia_Residual))
dystopia_low
index=np.where(new_df['Dystopia_Residual']<dystopia_low)
index
new_df=new_df.drop(new_df.index[index])
new_df.shape
# Out:
# (136, 8)

# %%
plt.figure(figsize=(15,35))
graph=1

for column in new_df:
    if graph<=30:
        ax=plt.subplot(5,2,graph)
        sns.boxplot(new_df[column])
        plt.xlabel(column,fontsize=10)
        graph+=1
        
    plt.show()

# %%
Trust_high=(q3.Trust+(1.5*iqr.Trust))
Trust_high
# Out:
# 0.35812499999999997

# %%
index=np.where(new_df['Trust']>Trust_high)
index    #it shows that there is no outliers so we move forward
# Out:
# (array([], dtype=int64),)

# %%
sns.distplot(new_df['Trust'])
# Out:
# <AxesSubplot:xlabel='Trust', ylabel='Density'>

# %%
plt.figure(figsize=(20,20),facecolor='white')
plotnumber=1
for column in new_df:
    if plotnumber<=8:
        ax=plt.subplot(2,4,plotnumber)
        sns.distplot(new_df[column])
        plt.xlabel(column,fontsize=20)
        
    plotnumber+=1
    
plt.tight_layout()

# %%
new_df.describe()
# Out:
#             Score     Economy      Family      Health     Freedom       Trust  \
# count  136.000000  136.000000  136.000000  136.000000  136.000000  136.000000
# mean     5.322110    0.827431    1.001315    0.616842    0.412025    0.114879
# std      1.023229    0.376463    0.241011    0.242769    0.145959    0.082393
# min      2.905000    0.000000    0.353860    0.000000    0.000000    0.000000
# 25%      4.569500    0.546262    0.863468    0.434980    0.317630    0.058257
# 50%      5.193000    0.897780    1.029510    0.675635    0.416795    0.093710
# 75%      5.984750    1.127025    1.203692    0.788293    0.530485    0.152493
# max      7.561000    1.554220    1.402230    0.991110    0.662460    0.356370
#
#        Generosity  Dystopia_Residual
# count  136.000000         136.000000
# mean     0.219941           2.129694
# std      0.112012           0.499963
# min      0.000000           0.899910
# 25%      0.137407           1.791085
# 50%      0.205770           2.095415
# ...

# %%
x=new_df.drop(columns=['Score'])
y=new_df['Score']

# %%
#standardization of data
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
x_scaled=scalar.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=10)

# %%
#training the data
regression=LinearRegression()
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regression.score(x_train,y_train)#accuracy score on training data
# Out:
# 0.9999999316251953

# %%
regression.score(x_test,y_test)#accuracy score on test data
# Out:
# 0.9999998888437297

# %%
y_pred=regression.predict(x_test)
y_pred
# Out:
# array([5.09752498, 3.65504628, 5.85519528, 4.5715162 , 3.78081381,
#        5.14042431, 4.78647686, 5.42853199, 4.97121161, 4.67726234,
#        5.19378339, 6.30236212, 7.42686657, 7.3780822 , 4.41930939,
#        5.39869285, 4.78795218, 5.88979071, 5.69525229, 6.29469816,
#        4.292558  , 5.58864242, 6.9373364 , 5.975259  , 5.60463488,
#        5.79058194, 3.68090043, 5.07328789])

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('actual Happyness Score')
plt.ylabel('predicted Happyness Score')
plt.title('actual vs model prediction')
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
y_pred=regression.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.0432110495982006e-07

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.0002916377681277314

# %%
#check if the model is over ffitting or not by using regularization techniques LASSO and RIDGE
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV

# %%
lascv=LassoCV(alphas=None,max_iter=50,normalize=True)#lassoCv is giving best alpha(learning rate) after max_iterations
lascv.fit(x_train,y_train)
# Out:
# LassoCV(max_iter=50, normalize=True)

# %%
alpha=lascv.alpha_
alpha
# Out:
# 7.452848037124127e-05

# %%
las_lnrgsn=Lasso(alpha)
las_lnrgsn.fit(x_train,y_train)
# Out:
# Lasso(alpha=7.452848037124127e-05)

# %%
las_lnrgsn.score(x_test,y_test)
# Out:
# 0.9999998786157629

# %%
#the above score indecates that which is similar to accuracy score in the linear regression model so it shows that our model is not over fitting
